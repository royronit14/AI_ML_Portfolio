# %% [markdown]
# ## REST APIs

# %% [markdown]
# Rest APIs function by sending a request, the request is communicated via HTTP message. The HTTP message usually contains a JSON file. This contains instructions for what operation we would like the service or resource to perform. In a similar manner, API returns a response, via an HTTP message, this response is usually contained within a JSON

# %% [markdown]
# <p>In this lab, we will use the <a href=https://pypi.org/project/nba-api/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01>NBA API</a> to determine how well the Golden State Warriors performed against the Toronto Raptors. We will use the API to determine the number of points the Golden State Warriors won or lost by for each game. So if the value is three, the Golden State Warriors won by three points. Similarly it the  Golden State Warriors lost  by two points the result will be negative two. The API will handle a lot of the details, such a Endpoints and Authentication. </p>

# %%
# !pip install nba_api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nba_api
#   Downloading nba_api-1.10.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy>=1.26.0 (from nba_api)
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas>=2.1.0 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from nba_api) (2.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from pandas>=2.1.0->nba_api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from pandas>=2.1.0->nba_api) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from pandas>=2.1.0->nba_api) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\baba_\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->nba_api) (1.16.0)
# Downloading nba_api-1.10.0-py3-none-any.whl (285 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.9 MB 11.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.9 MB 11.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.9 MB 11.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.9 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/12.9 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.9 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.9 MB 1.2 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/12.9 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/12.9 MB 1.3 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.9 MB 1.1 MB/s eta 0:00:10
#    -------- ------------------------------- 2.9/12.9 MB 1.2 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/12.9 MB 1.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.4/12.9 MB 1.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.9 MB 1.2 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/12.9 MB 1.2 MB/s eta 0:00:08
#    ------------- -------------------------- 4.2/12.9 MB 1.2 MB/s eta 0:00:08
#    ------------- -------------------------- 4.5/12.9 MB 1.2 MB/s eta 0:00:08
#    ------------- -------------------------- 4.5/12.9 MB 1.2 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.9 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/12.9 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/12.9 MB 1.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.2/12.9 MB 1.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.9 MB 1.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.8/12.9 MB 1.1 MB/s eta 0:00:07
#    ------------------ --------------------- 6.0/12.9 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.9 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.9 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.9 MB 1.1 MB/s eta 0:00:07
#    -------------------- ------------------- 6.6/12.9 MB 1.0 MB/s eta 0:00:07
#    --------------------- ------------------ 6.8/12.9 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.9 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 7.1/12.9 MB 1.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 7.3/12.9 MB 1.0 MB/s eta 0:00:06
#    ---------------------- ----------------- 7.3/12.9 MB 1.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.6/12.9 MB 1.0 MB/s eta 0:00:06
#    ------------------------ --------------- 7.9/12.9 MB 1.0 MB/s eta 0:00:06
#    ------------------------- -------------- 8.1/12.9 MB 1.0 MB/s eta 0:00:05
#    -------------------------- ------------- 8.4/12.9 MB 1.0 MB/s eta 0:00:05
#    -------------------------- ------------- 8.7/12.9 MB 1.0 MB/s eta 0:00:05
#    -------------------------- ------------- 8.7/12.9 MB 1.0 MB/s eta 0:00:05
#    --------------------------- ------------ 8.9/12.9 MB 1.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 9.2/12.9 MB 995.5 kB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.9 MB 997.0 kB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------------ --------- 9.7/12.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------------- -------- 10.2/12.9 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 10.2/12.9 MB 1.0 MB/s eta 0:00:03
#    -------------------------------- ------- 10.5/12.9 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.7/12.9 MB 1.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 11.0/12.9 MB 1.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/12.9 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/12.9 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/12.9 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/12.9 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/12.9 MB 984.3 kB/s eta 0:00:02
#    ------------------------------------ --- 11.8/12.9 MB 984.3 kB/s eta 0:00:02
#    ------------------------------------- -- 12.1/12.9 MB 971.7 kB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 969.6 kB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 969.6 kB/s eta 0:00:01
#    ---------------------------------------  12.6/12.9 MB 967.5 kB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 967.9 kB/s eta 0:00:00
# Installing collected packages: numpy, nba_api
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 1.25.2
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-1.25.2:
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-1.25.2
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    -------------------- ------------------- 1/2 [nba_api]
#    ---------------------------------------- 2/2 [nba_api]
#
# Successfully installed nba_api-1.10.0 numpy-2.2.6

# %%
from nba_api.stats.static import teams
import matplotlib.pyplot as plt
import pandas as pd

# %%
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %% [markdown]
# The method <code>get_teams()</code> returns a list of dictionaries.

# %%
nba_teams = teams.get_teams()

# %%
nba_teams[0:3]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %%
dict_nba_team=one_dict(nba_teams)
df_teams=pd.DataFrame(dict_nba_team)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966
